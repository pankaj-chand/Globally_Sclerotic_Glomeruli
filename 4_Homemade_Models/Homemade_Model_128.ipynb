# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Copying files: 5758 files [00:01, 3117.06 files/s]

# %%
from PIL import Image
import os

# Specify the paths to your train, val, and test folders containing your PNG images
train_folder = "/content/output/train"
val_folder = "/content/output/val"
test_folder = "/content/output/test"

def load_images_and_labels(folder_path):
    x_data = []
    y_data = []

    for subfolder in os.listdir(folder_path):
        subfolder_path = os.path.join(folder_path, subfolder)
        if os.path.isdir(subfolder_path):
            label = int(subfolder.split('_')[0])  # Assuming the folder names are 0 or 1

            for image_name in os.listdir(subfolder_path):
                image_path = os.path.join(subfolder_path, image_name)

                # Open image and convert to numpy array
                img = Image.open(image_path)
                img_array = np.array(img)

                # Append data to arrays
                x_data.append(img_array)
                y_data.append(label)

    return np.array(x_data), np.array(y_data)

# Load train data
x_train, y_train = load_images_and_labels(train_folder)

# Load validation data
x_val, y_val = load_images_and_labels(val_folder)

# Load test data
x_test, y_test = load_images_and_labels(test_folder)

# Now, x_train, y_train, x_val, y_val, x_test, y_test contain your image data and labels in NumPy arrays.

# Print the shape of the resulting array
print("Shape of x_train:", x_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of x_val:", x_val.shape)
print("Shape of y_val:", y_val.shape)
print("Shape of x_test:", x_test.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of x_train: (4606, 128, 128, 3)
# Shape of y_train: (4606,)
# Shape of x_val: (575, 128, 128, 3)
# Shape of y_val: (575,)
# Shape of x_test: (577, 128, 128, 3)
# Shape of y_test: (577,)

# %%
# Normalize the data to speed up training
mean = np.mean(x_train)
std = np.std(x_train)
x_train = (x_train-mean)/(std+1e-7)
x_val = (x_val-mean)/(std+1e-7)
x_test = (x_test-mean)/(std+1e-7)

# let's look at the normalized values of a sample image
x_train[0]
# Out:
# array([[[1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         ...,
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792]],
#
#        [[1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         ...,
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792]],
#
#        [[1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         ...,
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792]],
#
#        ...,
#
#        [[1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         ...,
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792]],
#
#        [[1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         ...,
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792]],
#
#        [[1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         ...,
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792],
#         [1.32206792, 1.32206792, 1.32206792]]])

# %%
# let's display the labels
y_train
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
# Homemade Model 1: 3 CN layers, 2 Dense layers, NO MaxPooling, Increase Dropout to 0.3,
# add weight decay to optimizer, He initialization

initializer = initializers.HeNormal()

# Model 10 had a little overfitting due to 3 Dense layers
# Model 11 had no overfiting, but performance was less than Model 10

# So, add one CNN layer to Model 11 and increase Dropout to 0.3


# build the model

# number of hidden units variable
base_hidden_units = 16

# l2 regularization hyperparameter
weight_decay = 1e-4

# instantiate an empty sequential model
model = Sequential()

# CONV1
model.add(Conv2D(base_hidden_units, (3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay), bias_regularizer=regularizers.L2(weight_decay), kernel_initializer=initializer, input_shape=x_train.shape[1:]))
model.add(BatchNormalization())

# CONV2
model.add(Conv2D(2*base_hidden_units, (3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay), bias_regularizer=regularizers.L2(weight_decay), kernel_initializer=initializer))
model.add(BatchNormalization())

# CONV3
model.add(Conv2D(4*base_hidden_units, (3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(weight_decay), bias_regularizer=regularizers.L2(weight_decay), kernel_initializer=initializer))
model.add(BatchNormalization())

# FCN

model.add(Flatten())
model.add(Dropout(0.3))
model.add(Dense(64, activation = 'relu', kernel_regularizer=regularizers.l2(weight_decay), bias_regularizer=regularizers.L2(weight_decay), kernel_initializer=initializer))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(32, activation = 'relu', kernel_regularizer=regularizers.l2(weight_decay), bias_regularizer=regularizers.L2(weight_decay), kernel_initializer=initializer))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(weight_decay), bias_regularizer=regularizers.L2(weight_decay), kernel_initializer=initializer))

# print model summary
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 128, 128, 16)      448
#
#  batch_normalization_18 (Ba  (None, 128, 128, 16)      64
#  tchNormalization)
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 32)      4640
#
#  batch_normalization_19 (Ba  (None, 128, 128, 32)      128
#  tchNormalization)
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 64)      18496
#
#  batch_normalization_20 (Ba  (None, 128, 128, 64)      256
#  tchNormalization)
#
#  flatten_4 (Flatten)         (None, 1048576)           0
#
#  dropout_6 (Dropout)         (None, 1048576)           0
#
#  dense_10 (Dense)            (None, 64)                67108928
#
#  batch_normalization_21 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 32)                2080
#
#  batch_normalization_22 (Ba  (None, 32)                128
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_12 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 67135457 (256.10 MB)
# Trainable params: 67135041 (256.10 MB)
# Non-trainable params: 416 (1.62 KB)
# _________________________________________________________________

# %% [markdown]
# He initialization
# When your neural network is ReLU activated, He initialization is one of the methods you can choose to bring the variance of those outputs to approximately one (He et al., 2015).
#
# Although it attempts to do the same, He initialization is different than Xavier initialization (Kumar, 2017; He et al., 2015). This difference is related to the nonlinearities of the ReLU activation function, which make it non-differentiable at [latex]x = 0[/latex]. However, Kumar indeed proves mathematically that for the ReLU activation function, the best weight initialization strategy is to initialize the weights randomly but with this variance:
#
# \begin{equation} v^{2} = 2/N \end{equation}
#
# ...which is He initialization.
#
# ReLU activating networks, which are pretty much the standard ones today, benefit from the He initializer - which does the same thing, but with a different variance, namely [latex]2/N[/latex].
#
# Reference: https://github.com/christianversloot/machine-learning-articles/blob/main/he-xavier-initialization-activation-functions-choose-wisely.md

# %%
# data augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False
    )

# compute the data augmentation on the training set
datagen.fit(x_train)

# %%
# training
batch_size = 64
epochs=60

optimizer1 = keras.optimizers.Adam(learning_rate=0.0001,weight_decay=1e-6)


model.compile(loss='binary_crossentropy', optimizer=optimizer1, metrics=['accuracy'])

# %%
# Start timing
start_time = time.time()  # Record start time


history1 = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                steps_per_epoch=x_train.shape[0] // batch_size, epochs=epochs,
                validation_data=(x_val,y_val))

end_time = time.time()  # Record end time

training_time = end_time - start_time
print("Training time: {} seconds".format(training_time))
# Out:
# <ipython-input-18-5ded50dafd2d>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history1 = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
# Epoch 1/60
# 71/71 [==============================] - 55s 522ms/step - loss: 0.7057 - accuracy: 0.7215 - val_loss: 0.6869 - val_accuracy: 0.7130
# Epoch 2/60
# 71/71 [==============================] - 24s 331ms/step - loss: 0.4644 - accuracy: 0.8633 - val_loss: 0.3840 - val_accuracy: 0.8783
# Epoch 3/60
# 71/71 [==============================] - 25s 347ms/step - loss: 0.4236 - accuracy: 0.8840 - val_loss: 0.2917 - val_accuracy: 0.9113
# Epoch 4/60
# 71/71 [==============================] - 23s 323ms/step - loss: 0.4055 - accuracy: 0.9038 - val_loss: 0.2531 - val_accuracy: 0.9426
# Epoch 5/60
# 71/71 [==============================] - 22s 311ms/step - loss: 0.3626 - accuracy: 0.9212 - val_loss: 0.2594 - val_accuracy: 0.9287
# Epoch 6/60
# 71/71 [==============================] - 23s 319ms/step - loss: 0.3379 - accuracy: 0.9232 - val_loss: 0.2246 - val_accuracy: 0.9443
# Epoch 7/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.3420 - accuracy: 0.9287 - val_loss: 0.2207 - val_accuracy: 0.9548
# Epoch 8/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.3294 - accuracy: 0.9271 - val_loss: 0.2163 - val_accuracy: 0.9530
# Epoch 9/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.3310 - accuracy: 0.9269 - val_loss: 0.2095 - val_accuracy: 0.9530
# Epoch 10/60
# 71/71 [==============================] - 23s 326ms/step - loss: 0.3079 - accuracy: 0.9364 - val_loss: 0.2060 - val_accuracy: 0.9513
# Epoch 11/60
# 71/71 [==============================] - 23s 327ms/step - loss: 0.3214 - accuracy: 0.9344 - val_loss: 0.1960 - val_accuracy: 0.9617
# Epoch 12/60
# 71/71 [==============================] - 22s 313ms/step - loss: 0.3014 - accuracy: 0.9366 - val_loss: 0.1933 - val_accuracy: 0.9548
# Epoch 13/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.2822 - accuracy: 0.9401 - val_loss: 0.2008 - val_accuracy: 0.9548
# Epoch 14/60
# 71/71 [==============================] - 23s 325ms/step - loss: 0.2790 - accuracy: 0.9441 - val_loss: 0.1940 - val_accuracy: 0.9583
# Epoch 15/60
# 71/71 [==============================] - 23s 325ms/step - loss: 0.2777 - accuracy: 0.9447 - val_loss: 0.1879 - val_accuracy: 0.9565
# Epoch 16/60
# 71/71 [==============================] - 23s 328ms/step - loss: 0.2692 - accuracy: 0.9461 - val_loss: 0.1899 - val_accuracy: 0.9530
# Epoch 17/60
# 71/71 [==============================] - 23s 327ms/step - loss: 0.2680 - accuracy: 0.9511 - val_loss: 0.1790 - val_accuracy: 0.9635
# Epoch 18/60
# 71/71 [==============================] - 22s 314ms/step - loss: 0.2650 - accuracy: 0.9472 - val_loss: 0.1806 - val_accuracy: 0.9565
# Epoch 19/60
# 71/71 [==============================] - 23s 317ms/step - loss: 0.2710 - accuracy: 0.9472 - val_loss: 0.1694 - val_accuracy: 0.9704
# Epoch 20/60
# 71/71 [==============================] - 22s 310ms/step - loss: 0.2629 - accuracy: 0.9452 - val_loss: 0.1776 - val_accuracy: 0.9600
# Epoch 21/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.2608 - accuracy: 0.9480 - val_loss: 0.1948 - val_accuracy: 0.9617
# Epoch 22/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.2577 - accuracy: 0.9467 - val_loss: 0.1673 - val_accuracy: 0.9635
# Epoch 23/60
# 71/71 [==============================] - 23s 322ms/step - loss: 0.2499 - accuracy: 0.9540 - val_loss: 0.1765 - val_accuracy: 0.9617
# Epoch 24/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.2480 - accuracy: 0.9529 - val_loss: 0.1669 - val_accuracy: 0.9722
# Epoch 25/60
# 71/71 [==============================] - 23s 323ms/step - loss: 0.2361 - accuracy: 0.9557 - val_loss: 0.1642 - val_accuracy: 0.9652
# Epoch 26/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.2399 - accuracy: 0.9531 - val_loss: 0.1602 - val_accuracy: 0.9687
# Epoch 27/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.2352 - accuracy: 0.9531 - val_loss: 0.1733 - val_accuracy: 0.9670
# Epoch 28/60
# 71/71 [==============================] - 23s 325ms/step - loss: 0.2504 - accuracy: 0.9549 - val_loss: 0.1781 - val_accuracy: 0.9687
# Epoch 29/60
# 71/71 [==============================] - 23s 325ms/step - loss: 0.2364 - accuracy: 0.9540 - val_loss: 0.1612 - val_accuracy: 0.9739
# Epoch 30/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.2278 - accuracy: 0.9599 - val_loss: 0.1948 - val_accuracy: 0.9635
# Epoch 31/60
# 71/71 [==============================] - 23s 316ms/step - loss: 0.2389 - accuracy: 0.9542 - val_loss: 0.1664 - val_accuracy: 0.9739
# Epoch 32/60
# 71/71 [==============================] - 23s 326ms/step - loss: 0.2318 - accuracy: 0.9557 - val_loss: 0.1655 - val_accuracy: 0.9670
# Epoch 33/60
# 71/71 [==============================] - 23s 325ms/step - loss: 0.2381 - accuracy: 0.9568 - val_loss: 0.1676 - val_accuracy: 0.9739
# Epoch 34/60
# 71/71 [==============================] - 23s 325ms/step - loss: 0.2187 - accuracy: 0.9637 - val_loss: 0.2105 - val_accuracy: 0.9583
# Epoch 35/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.2180 - accuracy: 0.9606 - val_loss: 0.1591 - val_accuracy: 0.9722
# Epoch 36/60
# 71/71 [==============================] - 22s 305ms/step - loss: 0.2184 - accuracy: 0.9615 - val_loss: 0.2344 - val_accuracy: 0.9426
# Epoch 37/60
# 71/71 [==============================] - 23s 323ms/step - loss: 0.2235 - accuracy: 0.9560 - val_loss: 0.2572 - val_accuracy: 0.9374
# Epoch 38/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.2363 - accuracy: 0.9584 - val_loss: 0.1568 - val_accuracy: 0.9809
# Epoch 39/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.2294 - accuracy: 0.9595 - val_loss: 0.1582 - val_accuracy: 0.9757
# Epoch 40/60
# 71/71 [==============================] - 22s 311ms/step - loss: 0.2452 - accuracy: 0.9555 - val_loss: 0.1634 - val_accuracy: 0.9739
# Epoch 41/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.2357 - accuracy: 0.9540 - val_loss: 0.2190 - val_accuracy: 0.9617
# Epoch 42/60
# 71/71 [==============================] - 23s 325ms/step - loss: 0.2226 - accuracy: 0.9626 - val_loss: 0.1705 - val_accuracy: 0.9757
# Epoch 43/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.2233 - accuracy: 0.9608 - val_loss: 0.1583 - val_accuracy: 0.9739
# Epoch 44/60
# 71/71 [==============================] - 23s 314ms/step - loss: 0.2326 - accuracy: 0.9575 - val_loss: 0.1578 - val_accuracy: 0.9791
# Epoch 45/60
# 71/71 [==============================] - 23s 325ms/step - loss: 0.2089 - accuracy: 0.9648 - val_loss: 0.1590 - val_accuracy: 0.9791
# Epoch 46/60
# 71/71 [==============================] - 23s 323ms/step - loss: 0.2028 - accuracy: 0.9687 - val_loss: 0.1674 - val_accuracy: 0.9757
# Epoch 47/60
# 71/71 [==============================] - 23s 323ms/step - loss: 0.2193 - accuracy: 0.9643 - val_loss: 0.1613 - val_accuracy: 0.9826
# Epoch 48/60
# 71/71 [==============================] - 23s 319ms/step - loss: 0.2195 - accuracy: 0.9624 - val_loss: 0.1549 - val_accuracy: 0.9861
# Epoch 49/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.2122 - accuracy: 0.9665 - val_loss: 0.2542 - val_accuracy: 0.9548
# Epoch 50/60
# 71/71 [==============================] - 23s 322ms/step - loss: 0.2205 - accuracy: 0.9646 - val_loss: 0.1663 - val_accuracy: 0.9774
# Epoch 51/60
# 71/71 [==============================] - 22s 309ms/step - loss: 0.2063 - accuracy: 0.9696 - val_loss: 0.1762 - val_accuracy: 0.9791
# Epoch 52/60
# 71/71 [==============================] - 23s 324ms/step - loss: 0.2159 - accuracy: 0.9650 - val_loss: 0.1861 - val_accuracy: 0.9722
# Epoch 53/60
# 71/71 [==============================] - 22s 300ms/step - loss: 0.2086 - accuracy: 0.9661 - val_loss: 0.1948 - val_accuracy: 0.9687
# Epoch 54/60
# 71/71 [==============================] - 24s 337ms/step - loss: 0.2301 - accuracy: 0.9621 - val_loss: 0.1958 - val_accuracy: 0.9739
# Epoch 55/60
# 71/71 [==============================] - 23s 321ms/step - loss: 0.2298 - accuracy: 0.9641 - val_loss: 0.2591 - val_accuracy: 0.9443
# Epoch 56/60
# 71/71 [==============================] - 22s 311ms/step - loss: 0.2316 - accuracy: 0.9617 - val_loss: 0.3322 - val_accuracy: 0.9235
# Epoch 57/60
# 71/71 [==============================] - 23s 323ms/step - loss: 0.2084 - accuracy: 0.9683 - val_loss: 0.2158 - val_accuracy: 0.9600
# Epoch 58/60
# 71/71 [==============================] - 23s 325ms/step - loss: 0.2298 - accuracy: 0.9646 - val_loss: 0.2462 - val_accuracy: 0.9670
# Epoch 59/60
# 71/71 [==============================] - 23s 323ms/step - loss: 0.2172 - accuracy: 0.9716 - val_loss: 0.2748 - val_accuracy: 0.9478
# Epoch 60/60
# 71/71 [==============================] - 23s 325ms/step - loss: 0.2054 - accuracy: 0.9703 - val_loss: 0.2024 - val_accuracy: 0.9687

# %%
# evaluating the model
scores = model.evaluate(x_test, y_test, batch_size=128, verbose=1)
print('\nTest result: %.3f loss: %.3f' % (scores[1]*100,scores[0]))
# Out:
# 5/5 [==============================] - 3s 329ms/step - loss: 0.1921 - accuracy: 0.9757
#
# Test result: 97.574 loss: 0.192

# %%
# plot learning curves of model accuracy
plt.plot(history1.history['accuracy'], label='train')
plt.plot(history1.history['val_accuracy'], label='dev')
plt.legend()
plt.savefig('HomemadeModel1.png')
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

y_proba = model.predict(x_test)
# Threshold probabilities to get binary predictions
threshold = 0.5
y_pred = (y_proba > threshold).astype(int)

# Compute confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 19/19 [==============================] - 1s 29ms/step

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, target_names=['Non-Sclerotic ', 'Sclerotic']))
# Out:
#                 precision    recall  f1-score   support
#
# Non-Sclerotic        0.98      0.99      0.99       471
#      Sclerotic       0.94      0.92      0.93       106
#
#       accuracy                           0.98       577
#      macro avg       0.96      0.96      0.96       577
#   weighted avg       0.98      0.98      0.98       577

# %%
from sklearn.metrics import roc_curve, auc

# Calculate the false positive rate (FPR), true positive rate (TPR), and threshold values
fpr, tpr, thresholds = roc_curve(y_test, y_proba)

# Calculate the AUC (Area Under the Curve)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.plot(fpr, tpr, color='blue', label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='red', linestyle='--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
#plt.savefig('.png')
plt.show()

# %% [markdown]
# Ideal Threshold

# %%
import pandas as pd
i = np.arange(len(tpr))
roc = pd.DataFrame({'tf' : pd.Series(tpr-(1-fpr), index=i), 'thresholds' : pd.Series(thresholds, index=i)})
ideal_roc_thresh = roc.iloc[(roc.tf-0).abs().argsort()[:1]]  #Locate the point where the value is close to 0
print("Ideal threshold is: ", ideal_roc_thresh['thresholds'])
# Out:
# Ideal threshold is:  17    0.207789
# Name: thresholds, dtype: float32

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

y_proba = model.predict(x_test)
# Threshold probabilities to get binary predictions
threshold =  0.207789
y_pred = (y_proba > threshold).astype(int)

# Compute confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 19/19 [==============================] - 0s 19ms/step

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, target_names=['Non-Sclerotic ', 'Sclerotic']))
# Out:
#                 precision    recall  f1-score   support
#
# Non-Sclerotic        0.99      0.96      0.97       471
#      Sclerotic       0.83      0.95      0.89       106
#
#       accuracy                           0.96       577
#      macro avg       0.91      0.96      0.93       577
#   weighted avg       0.96      0.96      0.96       577

# %%
from sklearn.metrics import roc_curve, auc

# Calculate the false positive rate (FPR), true positive rate (TPR), and threshold values
fpr, tpr, thresholds = roc_curve(y_test, y_proba)

# Calculate the AUC (Area Under the Curve)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.plot(fpr, tpr, color='blue', label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='red', linestyle='--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
#plt.savefig('VGG16_9epochs_ver2_roc_auc.png')
plt.show()

# %%
# Save the model
model.save('HomeMade_128x128.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
